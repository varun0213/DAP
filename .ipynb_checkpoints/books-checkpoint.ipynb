# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from dagster import job, op
import pandas as pd
from pymongo import MongoClient

# %%
data = pd.read_csv("C:/Users/varun/Desktop/DAP/books_scraped.csv")
data.head()
# Out:
#                                    Title       Book_category Star_rating  \
# 0                   A Light in the Attic              Poetry       Three
# 1                     Tipping the Velvet  Historical Fiction         One
# 2                             Soumission             Fiction         One
# 3                          Sharp Objects             Mystery        Four
# 4  Sapiens: A Brief History of Humankind             History        Five
#
#    Price     Stock  Quantity
# 0  51.77  In stock        22
# 1  53.74  In stock        20
# 2  50.10  In stock        20
# 3  47.82  In stock        20
# 4  54.23  In stock        20

# %%
data = data[(data['Book_category'] != 'Default')]
data = data[(data['Book_category'] != 'Add a comment')]

# %%
top_categories = data['Book_category'].value_counts().head(10)

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 8))
ax = sns.barplot(x=top_categories.index, y=top_categories.values, color='skyblue')

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.title('Most rated categories')
plt.xlabel('Category')
plt.ylabel('Numberof 5* ratings')

plt.xticks(rotation=45, ha='right')

plt.show()

# %%
category_counts = data.groupby('Book_category')['Quantity'].count().reset_index()

category_counts.columns = ['Book_Category', 'Quantity_Title_Book_Category_Count']

top_categories = category_counts.nlargest(14, 'Quantity_Title_Book_Category_Count')

other_category = pd.DataFrame({'Book_Category': ['Other'],
                               'Quantity_Title_Book_Category_Count': [category_counts['Quantity_Title_Book_Category_Count'].sum() - top_categories['Quantity_Title_Book_Category_Count'].sum()]})

combined_categories = pd.concat([top_categories, other_category])

sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))

colors = sns.color_palette("Set3", n_colors=len(combined_categories))

plt.pie(combined_categories['Quantity_Title_Book_Category_Count'], labels=None, autopct='%1.1f%%', startangle=90, pctdistance=0.85, labeldistance=1.05, colors=colors)

plt.title('Number of books by category in stock')

plt.legend(labels=combined_categories['Book_Category'], loc='center left', bbox_to_anchor=(1, 0.5), title='Категорії')

plt.show()

# %%
books_df = pd.read_csv('books_scraped.csv')

# %%
# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["books_data"]
collection = db["books"]

# %%
# Insert data into MongoDB
collection.insert_many(books_df.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65779a7b5fd26481602108be'), ObjectId('65779a7b5fd26481602108bf'), ObjectId('65779a7b5fd26481602108c0'), ObjectId('65779a7b5fd26481602108c1'), ObjectId('65779a7b5fd26481602108c2'), ObjectId('65779a7b5fd26481602108c3'), ObjectId('65779a7b5fd26481602108c4'), ObjectId('65779a7b5fd26481602108c5'), ObjectId('65779a7b5fd26481602108c6'), ObjectId('65779a7b5fd26481602108c7'), ObjectId('65779a7b5fd26481602108c8'), ObjectId('65779a7b5fd26481602108c9'), ObjectId('65779a7b5fd26481602108ca'), ObjectId('65779a7b5fd26481602108cb'), ObjectId('65779a7b5fd26481602108cc'), ObjectId('65779a7b5fd26481602108cd'), ObjectId('65779a7b5fd26481602108ce'), ObjectId('65779a7b5fd26481602108cf'), ObjectId('65779a7b5fd26481602108d0'), ObjectId('65779a7b5fd26481602108d1'), ObjectId('65779a7b5fd26481602108d2'), ObjectId('65779a7b5fd26481602108d3'), ObjectId('65779a7b5fd26481602108d4'), ObjectId('65779a7b5fd26481602108d5'), ObjectId('65779a7b5fd26481602108d6'), ObjectId('65779a7b5fd26481602108d7'), ObjectId('65779a7b5fd26481602108d8'), ObjectId('65779a7b5fd26481602108d9'), ObjectId('65779a7b5fd26481602108da'), ObjectId('65779a7b5fd26481602108db'), ObjectId('65779a7b5fd26481602108dc'), ObjectId('65779a7b5fd26481602108dd'), ObjectId('65779a7b5fd26481602108de'), ObjectId('65779a7b5fd26481602108df'), ObjectId('65779a7b5fd26481602108e0'), ObjectId('65779a7b5fd26481602108e1'), ObjectId('65779a7b5fd26481602108e2'), ObjectId('65779a7b5fd26481602108e3'), ObjectId('65779a7b5fd26481602108e4'), ObjectId('65779a7b5fd26481602108e5'), ObjectId('65779a7b5fd26481602108e6'), ObjectId('65779a7b5fd26481602108e7'), ObjectId('65779a7b5fd26481602108e8'), ObjectId('65779a7b5fd26481602108e9'), ObjectId('65779a7b5fd26481602108ea'), ObjectId('65779a7b5fd26481602108eb'), ObjectId('65779a7b5fd26481602108ec'), ObjectId('65779a7b5fd26481602108ed'), ObjectId('65779a7b5fd26481602108ee'), ObjectId('65779a7b5fd26481602108ef'), ObjectId('65779a7b5fd26481602108f0'), ObjectId('65779a7b5fd26481602108f1'), ObjectId('65779a7b5fd26481602108f2'), ObjectId('65779a7b5fd26481602108f3'), ObjectId('65779a7b5fd26481602108f4'), ObjectId('65779a7b5fd26481602108f5'), ObjectId('65779a7b5fd26481602108f6'), ObjectId('65779a7b5fd26481602108f7'), ObjectId('65779a7b5fd26481602108f8'), ObjectId('65779a7b5fd26481602108f9'), ObjectId('65779a7b5fd26481602108fa'), ObjectId('65779a7b5fd26481602108fb'), ObjectId('65779a7b5fd26481602108fc'), ObjectId('65779a7b5fd26481602108fd'), ObjectId('65779a7b5fd26481602108fe'), ObjectId('65779a7b5fd26481602108ff'), ObjectId('65779a7b5fd2648160210900'), ObjectId('65779a7b5fd2648160210901'), ObjectId('65779a7b5fd2648160210902'), ObjectId('65779a7b5fd2648160210903'), ObjectId('65779a7b5fd2648160210904'), ObjectId('65779a7b5fd2648160210905'), ObjectId('65779a7b5fd2648160210906'), ObjectId('65779a7b5fd2648160210907'), ObjectId('65779a7b5fd2648160210908'), ObjectId('65779a7b5fd2648160210909'), ObjectId('65779a7b5fd264816021090a'), ObjectId('65779a7b5fd264816021090b'), ObjectId('65779a7b5fd264816021090c'), ObjectId('65779a7b5fd264816021090d'), ObjectId('65779a7b5fd264816021090e'), ObjectId('65779a7b5fd264816021090f'), ObjectId('65779a7b5fd2648160210910'), ObjectId('65779a7b5fd2648160210911'), ObjectId('65779a7b5fd2648160210912'), ObjectId('65779a7b5fd2648160210913'), ObjectId('65779a7b5fd2648160210914'), ObjectId('65779a7b5fd2648160210915'), ObjectId('65779a7b5fd2648160210916'), ObjectId('65779a7b5fd2648160210917'), ObjectId('65779a7b5fd2648160210918'), ObjectId('65779a7b5fd2648160210919'), ObjectId('65779a7b5fd264816021091a'), ObjectId('65779a7b5fd264816021091b'), ObjectId('65779a7b5fd264816021091c'), ObjectId('65779a7b5fd264816021091d'), ObjectId('65779a7b5fd264816021091e'), ObjectId('65779a7b5fd264816021091f'), ObjectId('65779a7b5fd2648160210920'), ObjectId('65779a7b5fd2648160210921'), ObjectId('65779a7b5fd2648160210922'), ObjectId('65779a7b5fd2648160210923'), ObjectId('65779a7b5fd2648160210924'), ObjectId('65779a7b5fd2648160210925'), ObjectId('65779a7b5fd264816021 ...

# %%
from dagster import op
import psycopg2
import pandas as pd
 
@op
def load_into_postgres(context, data):
    # PostgreSQL connection details
    dbname = "postgres"
    user = "postgres"
    password = "Varun@2001"  # Add password if required
    host = "localhost"  # or your PostgreSQL server address
 
    # Connect to PostgreSQL
    conn = psycopg2.connect(dbname=postgres, user=postgres, password=Varun@2001, host=localhost)
    cur = conn.cursor()
 
    # Create the table
    cur.execute("""
    CREATE TABLE IF NOT EXISTS books (
        id SERIAL PRIMARY KEY,
        title VARCHAR(255),
        book_category VARCHAR(100),
        star_rating VARCHAR(10),
        price FLOAT,
        stock VARCHAR(20),
        quantity INT
    )
    """)
    conn.commit()
 
    # Insert data into the table
    insert_query = """
    INSERT INTO books (title, book_category, star_rating, price, stock, quantity) 
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    for record in data:
        cur.execute(insert_query, (record['Title'], record['Book_category'], record['Star_rating'], 
                                   record['Price'], record['Stock'], record['Quantity']))
        #conn.commit()
 
    conn.commit()
